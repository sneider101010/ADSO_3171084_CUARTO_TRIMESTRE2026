# %%
class Mueble:
 def __init__(self, material, color, propietario, ubicacion ):
  self.material = material
  self.color = color
  self.propietario = propietario
  self.ubicacion = ubicacion

 def get_info (self, momento):
    print(f"\nInformacion del Mueble({momento})")
    print("Material:", self.__material)
    print("Color:", self.__color)
    print("Propietario:", self.__propietario)
    print("Ubicacion:", self.___ubicacion)



 def set_material(self, nuevo_material):
    print("\nModificacion del Material")
    self.material = nuevo_material

 def set_color(self, nuevo_color):
   print("\nModificacion del Color")
   self.color = nuevo_color

 def set_propietario(self, nuevo_propietario):
   print("\nModificacion del Propietario")
   self.propietario = nuevo_propietario

 def set_ubicacion(self, nueva_ubicacion):
    print("\nModificacion de la Ubicacion")
    self.ubicacion = nueva_ubicacion



 mueble1 = Mueble("Madera", "Negro", "Carlos", "Oficina")
 mueble1.get_info("Antes de Modificar")


 mueble1.set_material("Metal")
 mueble1.set_color("Rojo")
 mueble1.set_propietario("Juan")
 mueble1.set_ubicacion  ("Sala")

 mueble1.get_info("Despues de Modificar")
# Out:
#   File "/tmp/ipython-input-785409431.py", line 8
#     def get_info (self, momento)
#                                 ^
# SyntaxError: expected ':'

# %%
import os
import sys

# Diccionario donde se almacena el registro de la ferreteria
inventario = {
    "001": {"nombre": "Martillo", "precio":150000, "stock": 10},
    "002": {"nombre": "Destornillador", "precio":50000, "stock": 20},
    "003": {"nombre": "Taladro", "precio":850000, "stock": 4},
    "004": {"nombre": "Llave inglesa", "precio":120000, "stock": 15}
}

factura_actual = []

def limpiar_pantalla():
    os.system("cls" if os.name == "nt" else "clear")

def mostrar_encabezado_tabla():
  print(f"{'ID':<6}{'NOMBRE':<20}{'PRECIO':<10}{'STOCK':<8}")
  print("-" * 48)

def mostrar_inventario():
  print("\n****** INVENTARIO COMPLETO ******")
  if not inventario:
    print("El inventario está vacío.")
  else:
    mostrar_encabezado_tabla()
    for id_prod, datos  in inventario.items():
        print(f"{id_prod:<6}{datos['nombre']:<20} ${datos['precio']:<10}{datos['stock']:<8}")
  print("-" * 48)

def buscar_producto_nombre():
    print("\n****** BUSCAR POR NOMBRE ******")
    termino = input("Ingrese el nombre del producto: ")
    encontrado = False
    print("Resultado de busqueda")
    mostrar_encabezado_tabla()
    for id_prod, datos in inventario.items():
        if termino.lower() in datos["nombre"].lower():
            print(f"{id_prod:<6}{datos['nombre']:<20} ${datos['precio']:<10}{datos['stock']:<8}")
            encontrado = True
    if not encontrado:
        print("No se encontraron productos con ese nombre.")
    print("-" * 48)

def agregar_nuevo_producto():
    print("\n****** AGREGAR NUEVO PRODUCTO ******")
    id_prod = input("Ingrese el ID del nuevo producto: ").strip()
    if id_prod in inventario:
        print(f"El producto con ID {id_prod} ya existe.")
    else:
        nombre = input("Nombre del producto: ")
        try:
            precio = float(input("Precio del producto: "))
            stock = int(input("Stock del producto: "))
            if precio < 0 or stock < 0:
                print("El precio y el stock no pueden ser negativos.")
                return
            inventario[id_prod] = {
                "nombre": nombre,
                "precio": precio,
                "stock": stock
            }
            print(f"El producto con ID {id_prod} ha sido agregado.")
        except ValueError:
            print("Error: El precio y stock deben ser números válidos.")

def modificar_producto():
    print("\n****** MODIFICAR PRODUCTO ******")
    mostrar_inventario()
    id_prod = input("Ingresar el ID del producto a modificar: ").strip()
    if id_prod in inventario:
        prod = inventario[id_prod]
        print(f"\nProducto seleccionado: {prod['nombre']}(stock:{prod['stock']} | Precio: ${prod['precio']})")
        print("1. Agregar unidades")
        print("2. Cambiar Precio")
        print("3. Cancelar")
        op_mod = input("Seleccionar una opcion: ")
        try:
            match op_mod:
              case "1":
                  cantidad = int(input("Cuantas unidades desea agregar?: "))
                  if cantidad > 0:
                    prod['stock'] += cantidad
                    print(f"Stock actualizado. Nuevo total: {prod['stock']} unidades.")
                  else:
                    print("La cantidad debe ser positiva.")

              case "2":
                  nuevo_precio = float(input("Ingresa el nuevo precio: "))
                  if nuevo_precio >= 0:
                    prod['precio'] = nuevo_precio # Changed from prod['stock']
                    print(f"Precio actualizado a: ${prod['precio']:.2f}.")
                  else:
                    print("El precio no puede ser negativo.")
              case "3":
                  print("Operación cancelada.")
              case _:
                  print("Opción inválida.")

        except ValueError:
            print("Error: Ingresar datos numéricos válidos.")
    else:
        print("Producto no encontrado.")

def eliminar_producto():
    print("\n****** ELIMINAR PRODUCTO ******")
    mostrar_inventario()
    id_prod = input("Ingresar el ID del producto que quiere eliminar: ").strip()
    if id_prod in inventario:
        print(f"Va a eliminar: {inventario[id_prod]['nombre']}")
        confirmacion = input("¿Está seguro? Esta acción no se puede deshacer (s/n): ").lower()
        if confirmacion == "s":
          eliminado = inventario.pop(id_prod)
          print(f"Producto '{eliminado['nombre']}' eliminado correctamente del inventario.")
        else:
          print("Operación cancelada.")
    else:
        print("ID no encontrado.")

def vender_producto():
    print("\n****** VENTA DE PRODUCTO ******")
    mostrar_inventario()
    buscar = input("¿Desea buscar el ID por nombre? (s/n): ").lower()
    if buscar == "s":
        buscar_producto_nombre()
    id_prod = input("Ingrese el ID del producto a vender: ").strip()
    if id_prod in inventario:
        prod = inventario[id_prod]
        try:
            print(f"Producto: {prod['nombre']}| Disponible: {prod['stock']}")
            cantidad = int(input("Cantidad a vender: "))
            if 0 < cantidad <= prod['stock']:
              subtotal = cantidad * prod['precio']
              prod['stock'] -= cantidad
              factura_actual.append({
                  "nombre": prod['nombre'],
                  "cantidad": cantidad,
                  "precio": prod['precio'],
                  "subtotal": subtotal
              })
              print(f"Agregado al carrito: ${subtotal:.2f}")
            else:
              print("Cantidad no válida o stock insuficiente.")
        except ValueError:
            print("Error: Ingrese un número válido. ")
    else:
        print("Producto no encontrado.")

def generar_factura():
    print("\n" + "="*40)
    print("FERRETERIA 'LE FALTA UN TORNILLO'")
    print("          FACTURA DE VENTA       ")
    print("="*40)
    if not factura_actual:
        print("No hay ítems en la factura actual.")
    else:
      total = 0
      print(f"{'CANT':<5}{'ARTICULO':<20}{'UNIDAD':<8}{'SUBTOTAL':<10}")
      print("-"*45)
      for item in factura_actual:
          print(f"{item['cantidad']:<5}{item['nombre']:<20} ${item['precio']:<7.2f} ${item['subtotal']:<9.2f}")
          total += item['subtotal']
      print("-"*45)
      print(f"Total a pagar: ${total:.2f}")
      print("="*40)
      if input("\n ¿Confirma el pago y cerrar venta? (s/n): ").lower() == "s":
        factura_actual.clear()
        print("Venta finalizada. Gracias por su compra.")
      else:
        print("Venta cancelada.")

def main():
    while True:
      print("\n============================ SISTEMA DE GESTION DE FERRETERIA===================================")
      print("1. Mostrar Inventario")
      print("2. Buscar por nombre")
      print("3. Vender (agregar a factura)")
      print("4. Generar factura")
      print("-" * 30)
      print("5. Agregar nuevo Producto")
      print("6. Modificar producto (Stock/precio)")
      print("7. Eliminar producto")
      print("8. Salir")
      opcion = input("Seleccione una opción: ").strip() # Get user input for option
      match opcion:
            case "1": mostrar_inventario()
            case "2": buscar_producto_nombre()
            case "3": vender_producto()
            case "4": generar_factura()
            case "5": agregar_nuevo_producto()
            case "6": modificar_producto()
            case "7": eliminar_producto()
            case "8":
                print("Saliendo del programa...")
                break
            case _:
                print("Opción no válida.")
      input("\nPresione Enter para continuar...")
      limpiar_pantalla()

if __name__ == "__main__":
     if sys.version_info < (3, 10):
        print("Error: Esta aplicación requiere Python 3.10 o superior.")
     else:
          main()
# Out:
# ============================ SISTEMA DE GESTION DE FERRETERIA===================================
# 1. Mostrar Inventario
# 2. Buscar por nombre
# 3. Vender (agregar a factura)
# 4. Generar factura
# ------------------------------
# 5. Agregar nuevo Producto
# 6. Modificar producto (Stock/precio)
# 7. Eliminar producto
# 8. Salir
#
# ****** AGREGAR NUEVO PRODUCTO ******
# El producto con ID melao ha sido agregado.
#
# ============================ SISTEMA DE GESTION DE FERRETERIA===================================
# 1. Mostrar Inventario
# 2. Buscar por nombre
# 3. Vender (agregar a factura)
# 4. Generar factura
# ------------------------------
# 5. Agregar nuevo Producto
# 6. Modificar producto (Stock/precio)
# 7. Eliminar producto
# 8. Salir
#
# ****** ELIMINAR PRODUCTO ******
#
# ****** INVENTARIO COMPLETO ******
# ID    NOMBRE              PRECIO    STOCK
# ------------------------------------------------
# 001   Martillo             $150000    10
# ...

# %%
from abc import ABC, abstractmethod
class Figura(ABC):
  @abstractmethod
  def calcular_area(self):
    pass
  def calcular_volumen(self):
    pass

class Circulo(Figura):
  def __init__(self, radio):
    self.radio = radio

  def calcular_area(self):
    return 3.1416 * (self.radio ** 2)

class Triangulo(Figura):
  def __init__(self, base, altura):
    self.base = base
    self.altura = altura

  def calcular_area(self):
    return (self.base * self.altura) / 2

class Rectangulo(Figura):
   def __init__(self, base, altura):
    self.base = base
    self.altura = altura

   def calcular_area(self):
    return self.base * self.altura

class Cuadrado(Figura):
   def __init__(self, lado):
    self.lado = lado

   def calcular_area(self):
    return self.lado ** 2

class Cubo(Figura):
   def __init__(self, lado):
    self.lado = lado

   def calcular_area(self):
    return 6 * (self.lado ** 2)

class Cilindro(Figura):
   def __init__(self, radio, altura):
    self.radio = radio
    self.altura = altura

   def calcular_area(self):
    return 2 * 3.1416 * self.radio * (self.radio + self.altura)

def mostrar_area(figura: Figura):
  print(f"Area: {figura.calcular_area():,.2f}")

def main():
    circulo1 = Circulo(5)
    mostrar_area(circulo1)
    triangulo1 = Triangulo(4,6)
    mostrar_area(triangulo1)
    rectangulo1 = Rectangulo(4,6)
    mostrar_area(rectangulo1)
    cubo1 = Cubo(4)
    mostrar_area(cubo1)
    cilindro1 = Cilindro(4,6)
    mostrar_area(cilindro1)
if __name__ == "__main__":
  main()
# Out:
# Area: 78.54
# Area: 12.00
# Area: 24.00
# Area: 96.00
# Area: 251.33

# %%
from abc import ABC, abstractmethod

class PersonalMedico(ABC):
    def __init__(self, nombre):
        self.__nombre = self._validar_nombre(nombre)

    @property
    def nombre(self):
        return self.__nombre

    @nombre.setter
    def nombre(self, nuevo_nombre):
        self.__nombre = self._validar_nombre(nuevo_nombre)

    def _validar_nombre(self, nombre):
        if not isinstance(nombre, str) or not nombre.strip():
            raise ValueError("El nombre no puede estar vacío y debe ser una cadena de texto.")
        return nombre.strip()

    @abstractmethod
    def trabajar(self):
        pass

class Doctor(PersonalMedico):
    def __init__(self, nombre):
        super().__init__(nombre)

    def trabajar(self):
        print(f"El doctor {self.nombre} está atendiendo pacientes en consulta.")

class Enfermero(PersonalMedico):
    def __init__(self, nombre):
        super().__init__(nombre)

    def trabajar(self):
        print(f"El enfermero {self.nombre} está asistiendo a los pacientes.")

class Cirujano(PersonalMedico):
    def __init__(self, nombre):
        super().__init__(nombre)

    def trabajar(self):
        print(f"El cirujano {self.nombre} está realizando una cirugía.")

def main():
    doctor1 = Doctor("Dr. Ana García")
    enfermero1 = Enfermero("Enf. Juan Pérez")
    cirujano1 = Cirujano("Dra. Laura Soto")

    personal_hospital = [doctor1, enfermero1, cirujano1]

    for personal in personal_hospital:
        personal.trabajar()

    # Example of name validation
    try:
        doctor2 = Doctor("")
    except ValueError as e:
        print(f"Error al crear Doctor: {e}")

    try:
        enfermero1.nombre = "   "
    except ValueError as e:
        print(f"Error al cambiar nombre a Enfermero: {e}")

if __name__ == "__main__":
    main()
# Out:
# El doctor Dr. Ana García está atendiendo pacientes en consulta.
# El enfermero Enf. Juan Pérez está asistiendo a los pacientes.
# El cirujano Dra. Laura Soto está realizando una cirugía.
# Error al crear Doctor: El nombre no puede estar vacío y debe ser una cadena de texto.
# Error al cambiar nombre a Enfermero: El nombre no puede estar vacío y debe ser una cadena de texto.

# %%
class Vehiculo:
  def Movimiento(self):
    print("El vehiculo se maneja")

class Moto(Vehiculo):
  def Movimiento(self):
    print("Una moto rueda por la carretera")
  pass
class Carro(Vehiculo):
  def Movimiento(self):
    print("Un carro esta barado")
  pass
class Avion(Vehiculo):
  def Movimiento(self):
    print("El avion vuela")
  pass
class Submarino(Vehiculo):
  def Movimiento(self):
    print("Un submarino bucea en el mar")
  pass

def main():
  vehiculo1 = Vehiculo()
  vehiculo1.Movimiento()
  moto1 = Moto()
  moto1.Movimiento()
  carro1 = Carro()
  carro1.Movimiento()
  avion1 = Avion()
  avion1.Movimiento()
  submarino1 = Submarino()
  submarino1.Movimiento()

if __name__ == "__main__":
  main()
# Out:
# El vehiculo se maneja
# Una moto rueda por la carretera
# Un carro esta barado
# El avion vuela
# Un submarino bucea en el mar

# %%
class Aprendiz:

    def __init__(self, nombre, apellido, id_aprendiz, estatura, edad, trimestre):
        self.__nombre = nombre
        self.__apellido = apellido
        self.__id = id_aprendiz
        self.__estatura = estatura
        self.__edad = edad
        self.__trimestre = trimestre

    def get_estatura(self):
        return self.__estatura

    def get_edad(self):
        return self.__edad

    def get_trimestre(self):
        return self.__trimestre

    def set_estatura(self, nueva_estatura):
        if isinstance(nueva_estatura, (int, float)) and nueva_estatura > 0:
            self.__estatura = nueva_estatura

    def set_edad(self, nueva_edad):
        if isinstance(nueva_edad, int) and nueva_edad > 0:
            self.__edad = nueva_edad

    def set_trimestre(self, nuevo_trimestre):
        if isinstance(nuevo_trimestre, int) and nuevo_trimestre > 0:
            self.__trimestre = nuevo_trimestre

    def Mostrar_todo(self):
        print("\n----- DATOS DEL APRENDIZ -----")
        print("Nombre:", self.__nombre)
        print("Apellido:", self.__apellido)
        print("ID:", self.__id)
        print("Estatura:", self.__estatura)
        print("Edad:", self.__edad)
        print("Trimestre:", self.__trimestre)
        print("------------------------------")


aprendiz1 = Aprendiz("Andres", " Sánchez", "54161", 1.70, 18, 1)

aprendiz1.Mostrar_todo()

nueva_estatura = float(input("Nueva estatura: "))
aprendiz1.set_estatura(nueva_estatura)

nueva_edad = int(input("Nueva edad: "))
aprendiz1.set_edad(nueva_edad)

nuevo_trimestre = int(input("Nuevo trimestre: "))
aprendiz1.set_trimestre(nuevo_trimestre)

aprendiz1.Mostrar_todo()
# Out:
# ----- DATOS DEL APRENDIZ -----
# Nombre: Juan Camilo
# Apellido: Hurtado Sánchez
# ID: 54161
# Estatura: 1.7
# Edad: 18
# Trimestre: 1
# ------------------------------
# Nueva estatura: 1.85
# Nueva edad: 18
# Nuevo trimestre: 4
#
# ----- DATOS DEL APRENDIZ -----
# Nombre: Juan Camilo
# Apellido: Hurtado Sánchez
# ID: 54161
# Estatura: 1.85
# Edad: 18
# Trimestre: 4
# ------------------------------

# %%
class Operacion: #Clave padre
  def __init__(self, dato1, dato2): #Constructor
    self.dato1 = dato1 #Atributos
    self.dato2 = dato2
  def Calcular(self): #Metodo
    print("Operaciones genericas en Matematicas")

class Suma(Operacion):
  def Calcular(self):
    resultado = self.dato1 + self.dato2
    print(f"La suma es: {resultado}")
class Resta(Operacion):
  def Calcular(self):
    resultado = self.dato1 - self.dato2
    print(f"La resta es: {resultado}")
class Multiplicacion(Operacion):
  def Calcular(self):
    resultado = self.dato1 * self.dato2
    print(f"La multiplicacion es: {resultado}")
class Division(Operacion):
  def Calcular(self):
    if self.dato2 != 0:
         resultado = self.dato1 / self.dato2
         print(f"La division es: {resultado}")
    else:
         print("No se puede dividir entre Cero")
def main():
  dato1 = float(input("Ingrese el primer dato: "))
  dato2 = float(input("Ingrese el segundo dato: "))
  operacion1 = Suma(dato1, dato2)
  operacion1.Calcular()
  operacion1 = Resta(dato1, dato2)
  operacion1.Calcular()
  operacion1 = Multiplicacion(dato1, dato2)
  operacion1.Calcular()
  operacion1 = Division(dato1, dato2)
  operacion1.Calcular()

if __name__ == "__main__":
  main()
# Out:
# Ingrese el primer dato: 423
# Ingrese el segundo dato: 2
# La suma es: 425.0
# La resta es: 421.0
# La multiplicacion es: 846.0
# La division es: 211.5

# %%
def agregar_cliente(lista_clientes, nombre):
    if isinstance(nombre, str) and 2 <= len(nombre) <= 50:
        lista_clientes.append(nombre.title())
        print(f"Cliente agregado {nombre.title()}")
    else:
        print("Debe agregar un nombre válido entre 2 y 50 caracteres")


def mostrar_clientes(lista_clientes):
    print("----- LISTA DE CLIENTES -----")
    for cliente in lista_clientes:
        print(f"- {cliente}")
    print("-----------------------------")


def modificar_cliente(lista_clientes, indice, nuevo_nombre):
    if not (isinstance(nuevo_nombre, str) and 2 <= len(nuevo_nombre) <= 50):
        print("Nombre de cliente inválido, debe tener entre 2 y 50 caracteres")
        return

    if 0 <= indice < len(lista_clientes):
        original = lista_clientes[indice]
        lista_clientes[indice] = nuevo_nombre.title()
        print(f"Cliente modificado de {original} a -> {nuevo_nombre.title()}")
    else:
        print("No existe este dato en la lista o índice incorrecto.")


def eliminar_cliente(lista_clientes, indice):
    if 0 <= indice < len(lista_clientes):
        eliminado = lista_clientes.pop(indice)
        print(f"Cliente eliminado: {eliminado}")
    else:
        print("No se puede eliminar el cliente, índice fuera de rango.")


def main():
    clientes = ["Ana", "Carlos", "Beatriz"]

    print("\n==============================")
    print("     Dylan maricon")
    print("==============================")
    mostrar_clientes(clientes)

    print("\n------------------------------")
    print("       AGREGAR CLIENTE")
    print("------------------------------")
    agregar_cliente(clientes, "Juan")
    mostrar_clientes(clientes)

    print("\n------------------------------")
    print("      MODIFICAR CLIENTE")
    print("------------------------------")
    modificar_cliente(clientes, 0, "Maria")
    mostrar_clientes(clientes)

    print("\n------------------------------")
    print("       ELIMINAR CLIENTE")
    print("------------------------------")
    eliminar_cliente(clientes, 2)
    mostrar_clientes(clientes)

    print("\n==============================")
    print("     PROCESO FINALIZADO")
    print("==============================")


if __name__ == "__main__":
    main()
# Out:
# ...
#      Dylan maricon
# ...
# ----- LISTA DE CLIENTES -----
# - Ana
# - Carlos
# - Beatriz
# -----------------------------
#
# ------------------------------
#        AGREGAR CLIENTE
# ------------------------------
# Cliente agregado Juan
# ----- LISTA DE CLIENTES -----
# - Ana
# - Carlos
# - Beatriz
# - Juan
# -----------------------------
#
# ------------------------------
#       MODIFICAR CLIENTE
# ------------------------------
# Cliente modificado de Ana a -> Maria
# ----- LISTA DE CLIENTES -----
# - Maria
# - Carlos
# - Beatriz
# - Juan
# -----------------------------
#
# ------------------------------
#        ELIMINAR CLIENTE
# ------------------------------
# Cliente eliminado: Beatriz
# ----- LISTA DE CLIENTES -----
# - Maria
# - Carlos
# - Juan
# -----------------------------
#
# ...
#      PROCESO FINALIZADO
# ...

# %%
class Mueble:
    def __init__(self, material, color, propietario, ubicacion):
        self.material = material
        self.color = color
        self.propietario = propietario
        self.ubicacion = ubicacion

    def get_info(self, momento):
        print(f"\nInformacion del Mueble ({momento})")
        print("Material:", self.material)
        print("Color:", self.color)
        print("Propietario:", self.propietario)
        print("Ubicacion:", self.ubicacion)

    def set_material(self, nuevo_material):
        print("\nModificacion del Material")
        self.material = nuevo_material

    def set_color(self, nuevo_color):
        print("\nModificacion del Color")
        self.color = nuevo_color

    def set_propietario(self, nuevo_propietario):
        print("\nModificacion del Propietario")
        self.propietario = nuevo_propietario

    def set_ubicacion(self, nueva_ubicacion):
        print("\nModificacion de la Ubicacion")
        self.ubicacion = nueva_ubicacion


mueble1 = Mueble("Madera", "Negro", "Carlos", "Oficina")
mueble1.get_info("Antes de Modificar")

mueble1.set_material("Metal")
mueble1.set_color("Rojo")
mueble1.set_propietario("Juan")
mueble1.set_ubicacion("Sala")

mueble1.get_info("Despues de Modificar")
# Out:
# Informacion del Mueble (Antes de Modificar)
# Material: Madera
# Color: Negro
# Propietario: Carlos
# Ubicacion: Oficina
#
# Modificacion del Material
#
# Modificacion del Color
#
# Modificacion del Propietario
#
# Modificacion de la Ubicacion
#
# Informacion del Mueble (Despues de Modificar)
# Material: Metal
# Color: Rojo
# Propietario: Juan
# Ubicacion: Sala

# %%
from abc import ABC, abstractmethod
class Empleado(ABC):
  def __init__(self, nombre: str) -> None:
    self._nombre = None
    self.nombre = nombre
  @property
  def nombre(self) -> str:
    return self._nombre
  @nombre.setter
  def nombre(self, valor: str) -> None:
    if isinstance( valor, str) and valor.strip():
      self._nombre = valor.strip()
    else:
      raise ValueError("El nombre debe ser una cadena no vacia")
  @abstractmethod
  def calcular_salario(self) -> None:
    pass

class Gerente(Empleado):
    def trabajar (self) -> None:
      print(f"{self.nombre} Esta realizando admistracion de la empresa.")
class Desarrollador (Empleado):
    def trabajar (self) -> None:
      print (f"{self.nombre} Esta programando.")
    def ejecutar_tarea( empleado:Empleado) -> None:
      empleado.trabajar()
    def main():
      print("===PROGRAMA DE EMPLEADOS===")
      desarrollador1 = Desarrollador("Juan")
      ejecutar_tarea(Gerente ("Carlos"))
      ejecutar_tarea(desarrollador1)
      print("/n********************************************")
      print("Actualizado el nombre del desarrollador")
      desarrollador1.nombre = "Luis"
      print(f"El nuevo desarrollador es {desarrollador1.nombre}")
      print("/N *************** fin **************************")
    if __name__ == "__main__":
      main()
# Out:
# ===PROGRAMA DE EMPLEADOS===
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_787/2799749252.py in <cell line: 0>()
#      20     def trabajar (self) -> None:
#      21       print(f"{self.nombre} Esta realizando admistracion de la empresa.")
# ---> 22 class Desarrollador (Empleado):
#      23     def trabajar (self) -> None:
#      24       print (f"{self.nombre} Esta programando.")
#
# /tmp/ipykernel_787/2799749252.py in Desarrollador()
#      36       print("/N *************** fin **************************")
#      37     if __name__ == "__main__":
# ---> 38       main()
#      39
#
# /tmp/ipykernel_787/2799749252.py in main()
#      27     def main():
#      28       print("===PROGRAMA DE EMPLEADOS===")
# ---> 29       desarrollador1 = Desarrollador("Juan")
#      30       ejecutar_tarea(Gerente ("Carlos"))
#      31       ejecutar_tarea(desarrollador1)
#
# ...

# %%
class Estudiante:
    def __init__(self, nombre, programa_formacion, edad, documento, promedio):
        self.nombre = nombre
        self.programa_formacion = programa_formacion
        self.edad = edad
        self.documento = documento
        self.promedio = promedio


    def get_nombre(self):
        return self.nombre

    def get_programa_formacion(self):
        return self.programa_formacion

    def get_edad(self):
        return self.edad

    def get_documento(self):
        return self.documento

    def get_promedio(self):
        return self.promedio

    def set_nombre(self, nuevo_nombre):
        if isinstance(nuevo_nombre, str):
            self.nombre = nuevo_nombre

    def set_programa_formacion(self, nuevo_programa_formacion):
        if isinstance(nuevo_programa_formacion, str):
            self.programa_formacion = nuevo_programa_formacion

    def set_edad(self, nueva_edad):
        if isinstance(nueva_edad, int) and nueva_edad > 0:
            self.edad = nueva_edad

    def set_documento(self, nuevo_documento):
        if isinstance(nuevo_documento, str):
            self.documento = nuevo_documento

    def set_promedio(self, nuevo_promedio):
        if isinstance(nuevo_promedio, (int, float)) and 0 <= nuevo_promedio <= 5:
            self.promedio = nuevo_promedio
        else:
            print("El promedio debe estar entre 0 y 5")


    def mostrar_info(self):
        print("Nombre:", self.nombre)
        print("Programa de formación:", self.programa_formacion)
        print("Edad:", self.edad)
        print("Documento:", self.documento)
        print("Promedio:", self.promedio)

    def main():
       estudiante1 = Estudiante("Carlos", "Ingeniería", 20, "12345", 4.5)
       estudiante2 = Estudiante("Juan", "ADSO", 22, "12452", 4.0)
       estudiante3 = Estudiante("Luis", "Derecho", 19, "789", 3.9)
       estudiante1.mostrar_info()
       estudiante2.mostrar_info()
       estudiante3.mostrar_info()


    if __name__ == "__main__":
       main()
# Out:
# Nombre: Carlos
# Programa de formación: Ingeniería
# Edad: 20
# Documento: 12345
# Promedio: 4.5
# Nombre: Juan
# Programa de formación: ADSO
# Edad: 22
# Documento: 12452
# Promedio: 4.0
# Nombre: Luis
# Programa de formación: Derecho
# Edad: 19
# Documento: 789
# Promedio: 3.9

# %%
class Vehiculo: #clase padre
 def mover(seft): # metodo
  print ("El vehiculo se esta moviendo")

class Carro( Vehiculo): # clas hija
 pass # ni atributos ni metodos (vacia)

def main(): # experiecia de usuario
  print("CLASE PADRE Y SU METODO\n")
  vehiculo1 = Vehiculo()
  vehiculo1. mover()
  print("Utilizaremos el metodo mover() de la clase padre")
  carro1 = Carro()
  carro1.mover
if __name__=="__main__":
  main()
# Out:
# CLASE PADRE Y SU METODO
#
# El vehiculo se esta moviendo
# Utilizaremos el metodo mover() de la clase padre

# %%
class Estudiante:
  def __init__(self, nombre, programa_formacion, edad, documento, promedio):
    self.nombre = nombre
    self.programa_formacion = programa_formacion
    self.edad = edad
    self.documento = documento
    self.promedio = promedio
  def get_nombre(self):
    return self.nombre
  def get_programa_formacion(self):
    return self.programa_formacion
  def get_edad(self):
    return self.edad
  def get_documento(self):
    return self.documento
  def get_promedio(self):
    return self.promedio
  def set_nombre(self, nuevo_nombre):
    if isinstance(nuevo_nombre,):
      self.nombre = nuevo_nombre
  def set_programa_formacion(self, nuevo_programa_formacion):
    if isinstance(nuevo_programa_formacion,):
  def set_edad(self, nueva_edad):
    if isinstance(nueva_edad,):
  def set_documento(self, nuevo_documento):
    if isinstance(nuevo_documento,):
  def set_promedio(self, nuevo_promedio):
    if 0 <= promedio <= 5:
      self.promedio = nuevo_promedio
    else:
        print("El promedio debe estar entre 0 y 5")
  def mostrar_info(self):
    print("Nombre:" , self.nombre)
  def mostrar_info(self):
    print("Programa de formacion:" , self.programa_formacion)
  def mostrar_info(self):
    print("Edad:" , self.edad)
  def mostrar_info(self):
    print("Documento:" , self.documento)
  def mostrar_info(self):
    print("Promedio:" , self.promedio)
# Out:
#   File "/tmp/ipython-input-1706272943.py", line 23
#     def set_edad(self, nueva_edad):
#     ^
# IndentationError: expected an indented block after 'if' statement on line 22

# %%
#Vamos a aplicar de forma tradicional
#Encapsulamientos y validaciones
class Libro:
    def __init__(self, titulo, precio):
       self.__titulo = titulo
       self.__precio = precio

    def get_titulo(self):
       return self.__titulo
    def get_precio(self):
       return self.__precio
    def set_precio(self, nuevo_precio):
       if isinstance(nuevo_precio, str):
         self.__precio = nuevo_precio
       else:
         print("El precio debe ser un numero entero o flotante \n")
    def set_titulo(self, nuevo_titulo):
       if isinstance(nuevo_titulo, str):
         self.__titulo = nuevo_titulo
       else:
         print("El titulo debe tener al menos 3 caracteres \n")
    def mostrar_info(self):
       print(f"Titulo:  {self.__titulo}")
       print(f"Precio:  ${self.__precio:,.2f}")

    def main():
       print("\n===SISTEMA DE LIBROS ADSO===")
       Libro1 = Libro ("El Quijote",80000)

       print("\nInformacion principal del Libro")
       Libro1.mostrar_info()
       print ("Precio actual del libro\n")
       print (f"Precio actual:", Libro1.get_precio())
       Libro1.set_precio("HOLA")
       Libro1.set_precio(90000)
       print(f"\nEl nuevo precio actualzado es:", Libro1.get_precio())
       Libro1.mostrar_info()
       print("=====PROGRAMA FINALIZADO====")

    if __name__ == "__main__":
        main()
# Out:
# ===SISTEMA DE LIBROS ADSO===
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3287642605.py in <cell line: 0>()
#       1 #Vamos a aplicar de forma tradicional
#       2 #Encapsulamientos y validaciones
# ----> 3 class Libro:
#       4     def __init__(self, titulo, precio):
#       5        self.__titulo = titulo
#
# /tmp/ipython-input-3287642605.py in Libro()
#      39
#      40     if __name__ == "__main__":
# ---> 41         main()
#      42
#
# /tmp/ipython-input-3287642605.py in main()
#      26     def main():
#      27        print("\n===SISTEMA DE LIBROS ADSO===")
# ---> 28        Libro1 = Libro ("El Quijote",80000)
#      29
#      30        print("\nInformacion principal del Libro")
#
# NameError: name 'Libro' is not defined

# %%
#Vamos a aplicar de forma tradicional
#Encapsulamientos y validaciones
class Libro:
    def __init__(self, titulo, precio):
       self.__titulo = titulo
       self.__precio = precio

    def get_titulo(self):
       return self.__titulo
    def get_precio(self):
       return self.__precio
    def set_precio(self, nuevo_precio):
       if isinstance(nuevo_precio, str):
         self.__precio = nuevo_precio
       else:
         print("El precio debe ser un numero entero o flotante \n")
    def set_titulo(self, nuevo_titulo):
       if isinstance(nuevo_titulo, str):
         self.__titulo = nuevo_titulo
       else:
         print("El titulo debe tener al menos 3 caracteres \n")
    def mostrar_info(self):
       print(f"Titulo:  {self.__titulo}")
       print(f"Precio:  ${self.__precio:,.2f}")

    def main():
       print("\n===SISTEMA DE LIBROS ADSO===")
       Libro1 = Libro ("El Quijote",80000)

       print("\nInformacion principal del Libro")
       Libro1.mostrar_info()
       print ("Precio actual del libro\n")
       print (f"Precio actual:", Libro1.get_precio())
       Libro1.set_precio("HOLA")
       Libro1.set_precio(90000)
       print(f"\nEl nuevo precio actualzado es:", Libro1.get_precio())
       Libro1.mostrar_info()
       print("=====PROGRAMA FINALIZADO====")

    if __name__ == "__main__":
        main()
# Out:
# ===SISTEMA DE LIBROS ADSO===
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3287642605.py in <cell line: 0>()
#       1 #Vamos a aplicar de forma tradicional
#       2 #Encapsulamientos y validaciones
# ----> 3 class Libro:
#       4     def __init__(self, titulo, precio):
#       5        self.__titulo = titulo
#
# /tmp/ipython-input-3287642605.py in Libro()
#      39
#      40     if __name__ == "__main__":
# ---> 41         main()
#      42
#
# /tmp/ipython-input-3287642605.py in main()
#      26     def main():
#      27        print("\n===SISTEMA DE LIBROS ADSO===")
# ---> 28        Libro1 = Libro ("El Quijote",80000)
#      29
#      30        print("\nInformacion principal del Libro")
#
# NameError: name 'Libro' is not defined

# %%
class Aprendiz:
    def __init__(self, id, nombre, apellido, edad, programa, trimestre, ambiente):
      self.__id = id
      self.__nombre = nombre
      self.__apellido = apellido
      self.__edad = edad
      self.__programa = programa
      self.__trimestre = trimestre
      self.__ambiente = ambiente

#Metodos

def get_id(self):
  return self.__id

def get_nombre(self):
  return self.__nombre

def get_apellido(self):
  return self.__apellido

def get_edad(self):
  return self.__edad

def get_programa(self):
  return self.__programa

def get_trimestre(self):
  return self.__trimestre

def get_ambiente(self):
  return self.__ambiente

def set_edad (self, nueva_edad):
  if isinstance(nueva_edad, (int)) and nueva_edad > 0:
    self.__edad = nueva_edad
  else:
    print("La edad debe ser un mayor o igual a 14")
def ser
# Out:
#   File "/tmp/ipython-input-428946238.py", line 39
#     def ser
#            ^
# SyntaxError: expected '('

# %%
class Libro:
 def __int__(self, titulo, precio):
  self.__titulo = titulo
  self.__precio = precio
#decoradores
# para el getter, osea mostrar los valores
# de las variables
@property
def titulo(self):
  return self.__titulo
@property #decorador para el getter
def precio(self):
  return self.__precio
# setter,modificar los valores de los atributos
@titulo.setter
def titulo(self, nuevo_titulo):
  if isinstance(nuevo_titulo, str):
    self.__titulo = nuevo_titulo

  else:
   print("El titulo debe tener al menos 3 caracteres")
   @precio.setter
   def precio(self, nuevo_precio):
    if isinstance(nuevo_precio, (int, float)) and nuevo_precio > 0:
     self.__precio = nuevo_precio
    else:
     print("El precio debe ser un numero entero o flotante")
